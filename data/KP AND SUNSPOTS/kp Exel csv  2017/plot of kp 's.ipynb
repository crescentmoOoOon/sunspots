# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pylab as plt

# %%
dfJan = pd.read_csv('../kp Exel csv  2017/kp2017Jan.csv')
dfFeb = pd.read_csv('../kp Exel csv  2017/kp2017Feb.csv')
dfMar = pd.read_csv('../kp Exel csv  2017/kp2017Mar.csv')
dfApr = pd.read_csv('../kp Exel csv  2017/kp2017Apr.csv')
dfMay = pd.read_csv('../kp Exel csv  2017/kp2017May.csv')
dfJun = pd.read_csv('../kp Exel csv  2017/kp2017Jun.csv')
dfJul = pd.read_csv('../kp Exel csv  2017/kp2017Jul.csv')
dfAug = pd.read_csv('../kp Exel csv  2017/kp2017Aug.csv')
dfSep = pd.read_csv('../kp Exel csv  2017/kp2017Sep.csv')
dfOct = pd.read_csv('../kp Exel csv  2017/kp2017Oct.csv')
dfNov = pd.read_csv('../kp Exel csv  2017/kp2017Nov.csv')
dfDec = pd.read_csv('../kp Exel csv  2017/kp2017Dec.csv')

# %%
df2017 = dfJan.append(dfFeb).append(dfMar).append(dfApr).append(dfMay).append(dfJun).append(dfJul).append(dfAug).append(dfSep).append(dfOct).append(dfNov).append(dfDec)

# %%
np.corrcoef(df2017['KP-MAX'],df2017['Ap'])
plt.plot(df2017['KP-MAX'],df2017['SUNSPOTS'],'-')

# %%
plt.plot(df2017['KP-MIN'],df2017['SUNSPOTS'],'-')

# %%
plt.plot(df2017['KP-AVE'],df2017['SUNSPOTS'],'-')

# %%
plt.plot(df2017['KP-MAX'],df2017['Ap'],'-')

# %%
plt.plot(df2017['Ap'],df2017['SUNSPOTS'],'-')
