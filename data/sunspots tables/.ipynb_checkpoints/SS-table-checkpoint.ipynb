# %%
from glob import glob

# %%
file_names = glob('*')

# %%
data=[]

for file_name in file_names:
    with open(file_name) as f:
        for line in f:
            data.append(line.split())

# %%
for i in data:
	print(i)
# Out:
# ['DAILY', 'AMERICAN', 'SUNSPOT', 'NUMBERS', '1992']
# ['===============================================================================']
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Yr', 'Day']
# ['-------------------------------------------------------------------------------']
# ['143', '220', '144', '102', '84', '32', '77', '73', '48', '89', '102', '67', '1992', '01']
# ['131', '210', '115', '90', '83', '47', '69', '97', '49', '95', '84', '61', '1992', '02']
# ['161', '182', '89', '77', '79', '74', '66', '100', '54', '104', '65', '58', '1992', '03']
# ['179', '178', '80', '62', '88', '88', '68', '103', '54', '120', '83', '59', '1992', '04']
# ['170', '166', '74', '60', '83', '81', '74', '92', '53', '129', '88', '49', '1992', '05']
# ['176', '155', '86', '55', '86', '78', '85', '90', '55', '130', '87', '42', '1992', '06']
# ['193', '158', '102', '58', '69', '67', '90', '101', '44', '110', '93', '31', '1992', '07']
# ...
